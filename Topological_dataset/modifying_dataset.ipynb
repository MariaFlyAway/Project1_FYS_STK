# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Load the terrain
terrain1 = imageio.v2.imread('6801_1_10m_z33.tif')
# Show the terrain
plt.figure()
plt.title('Terrain over Norway 1')
plt.imshow(terrain1, cmap='gray')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

terrain_arr = np.array(terrain1)

print(terrain_arr.shape)
# Out:
# c:\Users\maria\anaconda3\envs\fysstk3155\Lib\site-packages\imageio\plugins\_tifffile.py:8783: UserWarning: unexpected end of LZW stream (code 0)
#   warnings.warn("unexpected end of LZW stream (code %i)" % code)
# c:\Users\maria\anaconda3\envs\fysstk3155\Lib\site-packages\imageio\plugins\_tifffile.py:3675: UserWarning: invalid tile data
#   warnings.warn("invalid tile data")
# (5041, 5041)
